# %% [markdown]
# <a href="https://colab.research.google.com/github/tubagusalwasii/32602100121_TubagusAlwasi/blob/main/pengenalan_pola_hanacaraka.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount("/content/gdrive/")
# Out:
# Mounted at /content/gdrive/

# %%
import zipfile

filename = "/content/gdrive/My Drive/dataset.zip"
zip_ref = zipfile.ZipFile(filename)
zip_ref.extractall()
zip_ref.close()

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Membuat direktori train dan validation
base_dir = "/content/hanacaraka"
train_dir = os.path.join(base_dir, "train")
val_dir = os.path.join(base_dir, "val")

os.mkdir(train_dir)
os.mkdir(val_dir)

# Inisialisasi 20 folder karekter aksara jawa
ha_dir = os.path.join(base_dir, "ha")
na_dir = os.path.join(base_dir, "na")
ca_dir = os.path.join(base_dir, "ca")
ra_dir = os.path.join(base_dir, "ra")
ka_dir = os.path.join(base_dir, "ka")
da_dir = os.path.join(base_dir, "da")
ta_dir = os.path.join(base_dir, "ta")
sa_dir = os.path.join(base_dir, "sa")
wa_dir = os.path.join(base_dir, "wa")
la_dir = os.path.join(base_dir, "la")
pa_dir = os.path.join(base_dir, "pa")
dha_dir = os.path.join(base_dir, "dha")
ja_dir = os.path.join(base_dir, "ja")
ya_dir = os.path.join(base_dir, "ya")
nya_dir = os.path.join(base_dir, "nya")
ma_dir = os.path.join(base_dir, "ma")
ga_dir = os.path.join(base_dir, "ga")
ba_dir = os.path.join(base_dir, "ba")
tha_dir = os.path.join(base_dir, "tha")
nga_dir = os.path.join(base_dir, "nga")

# Membagi masing-masing folder karakter aksara jawa untuk data train dan
# validation dengan proporsi 80% dan 20%
train_ha, val_ha = train_test_split(os.listdir(ha_dir), test_size = 0.2)
train_na, val_na = train_test_split(os.listdir(na_dir), test_size = 0.2)
train_ca, val_ca = train_test_split(os.listdir(ca_dir), test_size = 0.2)
train_ra, val_ra = train_test_split(os.listdir(ra_dir), test_size = 0.2)
train_ka, val_ka = train_test_split(os.listdir(ka_dir), test_size = 0.2)
train_da, val_da = train_test_split(os.listdir(da_dir), test_size = 0.2)
train_ta, val_ta = train_test_split(os.listdir(ta_dir), test_size = 0.2)
train_sa, val_sa = train_test_split(os.listdir(sa_dir), test_size = 0.2)
train_wa, val_wa = train_test_split(os.listdir(wa_dir), test_size = 0.2)
train_la, val_la = train_test_split(os.listdir(la_dir), test_size = 0.2)
train_pa, val_pa = train_test_split(os.listdir(pa_dir), test_size = 0.2)
train_dha, val_dha = train_test_split(os.listdir(dha_dir), test_size = 0.2)
train_ja, val_ja = train_test_split(os.listdir(ja_dir), test_size = 0.2)
train_ya, val_ya = train_test_split(os.listdir(ya_dir), test_size = 0.2)
train_nya, val_nya = train_test_split(os.listdir(nya_dir), test_size = 0.2)
train_ma, val_ma = train_test_split(os.listdir(ma_dir), test_size = 0.2)
train_ga, val_ga = train_test_split(os.listdir(ga_dir), test_size = 0.2)
train_ba, val_ba = train_test_split(os.listdir(ba_dir), test_size = 0.2)
train_tha, val_tha = train_test_split(os.listdir(tha_dir), test_size = 0.2)
train_nga, val_nga = train_test_split(os.listdir(nga_dir), test_size = 0.2)

# Membuat 20 folder karekter aksara jawa pada direktori train dan validation
train_ha_dir = os.path.join(train_dir, "ha")
train_na_dir = os.path.join(train_dir, "na")
train_ca_dir = os.path.join(train_dir, "ca")
train_ra_dir = os.path.join(train_dir, "ra")
train_ka_dir = os.path.join(train_dir, "ka")
train_da_dir = os.path.join(train_dir, "da")
train_ta_dir = os.path.join(train_dir, "ta")
train_sa_dir = os.path.join(train_dir, "sa")
train_wa_dir = os.path.join(train_dir, "wa")
train_la_dir = os.path.join(train_dir, "la")
train_pa_dir = os.path.join(train_dir, "pa")
train_dha_dir = os.path.join(train_dir, "dha")
train_ja_dir = os.path.join(train_dir, "ja")
train_ya_dir = os.path.join(train_dir, "ya")
train_nya_dir = os.path.join(train_dir, "nya")
train_ma_dir = os.path.join(train_dir, "ma")
train_ga_dir = os.path.join(train_dir, "ga")
train_ba_dir = os.path.join(train_dir, "ba")
train_tha_dir = os.path.join(train_dir, "tha")
train_nga_dir = os.path.join(train_dir, "nga")

val_ha_dir = os.path.join(val_dir, "ha")
val_na_dir = os.path.join(val_dir, "na")
val_ca_dir = os.path.join(val_dir, "ca")
val_ra_dir = os.path.join(val_dir, "ra")
val_ka_dir = os.path.join(val_dir, "ka")
val_da_dir = os.path.join(val_dir, "da")
val_ta_dir = os.path.join(val_dir, "ta")
val_sa_dir = os.path.join(val_dir, "sa")
val_wa_dir = os.path.join(val_dir, "wa")
val_la_dir = os.path.join(val_dir, "la")
val_pa_dir = os.path.join(val_dir, "pa")
val_dha_dir = os.path.join(val_dir, "dha")
val_ja_dir = os.path.join(val_dir, "ja")
val_ya_dir = os.path.join(val_dir, "ya")
val_nya_dir = os.path.join(val_dir, "nya")
val_ma_dir = os.path.join(val_dir, "ma")
val_ga_dir = os.path.join(val_dir, "ga")
val_ba_dir = os.path.join(val_dir, "ba")
val_tha_dir = os.path.join(val_dir, "tha")
val_nga_dir = os.path.join(val_dir, "nga")

os.mkdir(train_ha_dir)
os.mkdir(train_na_dir)
os.mkdir(train_ca_dir)
os.mkdir(train_ra_dir)
os.mkdir(train_ka_dir)
os.mkdir(train_da_dir)
os.mkdir(train_ta_dir)
os.mkdir(train_sa_dir)
os.mkdir(train_wa_dir)
os.mkdir(train_la_dir)
os.mkdir(train_pa_dir)
os.mkdir(train_dha_dir)
os.mkdir(train_ja_dir)
os.mkdir(train_ya_dir)
os.mkdir(train_nya_dir)
os.mkdir(train_ma_dir)
os.mkdir(train_ga_dir)
os.mkdir(train_ba_dir)
os.mkdir(train_tha_dir)
os.mkdir(train_nga_dir)

os.mkdir(val_ha_dir)
os.mkdir(val_na_dir)
os.mkdir(val_ca_dir)
os.mkdir(val_ra_dir)
os.mkdir(val_ka_dir)
os.mkdir(val_da_dir)
os.mkdir(val_ta_dir)
os.mkdir(val_sa_dir)
os.mkdir(val_wa_dir)
os.mkdir(val_la_dir)
os.mkdir(val_pa_dir)
os.mkdir(val_dha_dir)
os.mkdir(val_ja_dir)
os.mkdir(val_ya_dir)
os.mkdir(val_nya_dir)
os.mkdir(val_ma_dir)
os.mkdir(val_ga_dir)
os.mkdir(val_ba_dir)
os.mkdir(val_tha_dir)
os.mkdir(val_nga_dir)

# Mengisi setiap folder karakter aksara jawa pada direktori train dan
# validation sesuai dengan proposi yang telah ditentukan.
for i in train_ha:
  shutil.copy(os.path.join(ha_dir, i), os.path.join(train_ha_dir, i))
for i in train_na:
  shutil.copy(os.path.join(na_dir, i), os.path.join(train_na_dir, i))
for i in train_ca:
  shutil.copy(os.path.join(ca_dir, i), os.path.join(train_ca_dir, i))
for i in train_ra:
  shutil.copy(os.path.join(ra_dir, i), os.path.join(train_ra_dir, i))
for i in train_ka:
  shutil.copy(os.path.join(ka_dir, i), os.path.join(train_ka_dir, i))
for i in train_da:
  shutil.copy(os.path.join(da_dir, i), os.path.join(train_da_dir, i))
for i in train_ta:
  shutil.copy(os.path.join(ta_dir, i), os.path.join(train_ta_dir, i))
for i in train_sa:
  shutil.copy(os.path.join(sa_dir, i), os.path.join(train_sa_dir, i))
for i in train_wa:
  shutil.copy(os.path.join(wa_dir, i), os.path.join(train_wa_dir, i))
for i in train_la:
  shutil.copy(os.path.join(la_dir, i), os.path.join(train_la_dir, i))
for i in train_pa:
  shutil.copy(os.path.join(pa_dir, i), os.path.join(train_pa_dir, i))
for i in train_dha:
  shutil.copy(os.path.join(dha_dir, i), os.path.join(train_dha_dir, i))
for i in train_ja:
  shutil.copy(os.path.join(ja_dir, i), os.path.join(train_ja_dir, i))
for i in train_ya:
  shutil.copy(os.path.join(ya_dir, i), os.path.join(train_ya_dir, i))
for i in train_nya:
  shutil.copy(os.path.join(nya_dir, i), os.path.join(train_nya_dir, i))
for i in train_ma:
  shutil.copy(os.path.join(ma_dir, i), os.path.join(train_ma_dir, i))
for i in train_ga:
  shutil.copy(os.path.join(ga_dir, i), os.path.join(train_ga_dir, i))
for i in train_ba:
  shutil.copy(os.path.join(ba_dir, i), os.path.join(train_ba_dir, i))
for i in train_tha:
  shutil.copy(os.path.join(tha_dir, i), os.path.join(train_tha_dir, i))
for i in train_nga:
  shutil.copy(os.path.join(nga_dir, i), os.path.join(train_nga_dir, i))

for i in val_ha:
  shutil.copy(os.path.join(ha_dir, i), os.path.join(val_ha_dir, i))
for i in val_na:
  shutil.copy(os.path.join(na_dir, i), os.path.join(val_na_dir, i))
for i in val_ca:
  shutil.copy(os.path.join(ca_dir, i), os.path.join(val_ca_dir, i))
for i in val_ra:
  shutil.copy(os.path.join(ra_dir, i), os.path.join(val_ra_dir, i))
for i in val_ka:
  shutil.copy(os.path.join(ka_dir, i), os.path.join(val_ka_dir, i))
for i in val_da:
  shutil.copy(os.path.join(da_dir, i), os.path.join(val_da_dir, i))
for i in val_ta:
  shutil.copy(os.path.join(ta_dir, i), os.path.join(val_ta_dir, i))
for i in val_sa:
  shutil.copy(os.path.join(sa_dir, i), os.path.join(val_sa_dir, i))
for i in val_wa:
  shutil.copy(os.path.join(wa_dir, i), os.path.join(val_wa_dir, i))
for i in val_la:
  shutil.copy(os.path.join(la_dir, i), os.path.join(val_la_dir, i))
for i in val_pa:
  shutil.copy(os.path.join(pa_dir, i), os.path.join(val_pa_dir, i))
for i in val_dha:
  shutil.copy(os.path.join(dha_dir, i), os.path.join(val_dha_dir, i))
for i in val_ja:
  shutil.copy(os.path.join(ja_dir, i), os.path.join(val_ja_dir, i))
for i in val_ya:
  shutil.copy(os.path.join(ya_dir, i), os.path.join(val_ya_dir, i))
for i in val_nya:
  shutil.copy(os.path.join(nya_dir, i), os.path.join(val_nya_dir, i))
for i in val_ma:
  shutil.copy(os.path.join(ma_dir, i), os.path.join(val_ma_dir, i))
for i in val_ga:
  shutil.copy(os.path.join(ga_dir, i), os.path.join(val_ga_dir, i))
for i in val_ba:
  shutil.copy(os.path.join(ba_dir, i), os.path.join(val_ba_dir, i))
for i in val_tha:
  shutil.copy(os.path.join(tha_dir, i), os.path.join(val_tha_dir, i))
for i in val_nga:
  shutil.copy(os.path.join(nga_dir, i), os.path.join(val_nga_dir, i))

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 20,
    shear_range = 0.2,
    zoom_range = 0.2,
    fill_mode = "nearest"
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 20,
    shear_range = 0.2,
    zoom_range = 0.2,
    fill_mode = "nearest"
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (100, 100),
    batch_size = 32,
    class_mode = "categorical",    # Gunakan categorical untuk klasifikasi 3 kelas atau lebih,
    color_mode = "grayscale"        # untuk klasifikasi dua kelas gunakan binary
)

validation_generator = validation_datagen.flow_from_directory(
    val_dir,
    target_size = (100, 100),
    batch_size = 32,
    class_mode = "categorical",    # Gunakan categorical untuk klasifikasi 3 kelas atau lebih
    color_mode = "grayscale"        # untuk klasifikasi dua kelas gunakan binary
)
# Out:
# Found 8160 images belonging to 20 classes.
# Found 2040 images belonging to 20 classes.

# %%
print(train_generator.class_indices)
# Out:
# {'ba': 0, 'ca': 1, 'da': 2, 'dha': 3, 'ga': 4, 'ha': 5, 'ja': 6, 'ka': 7, 'la': 8, 'ma': 9, 'na': 10, 'nga': 11, 'nya': 12, 'pa': 13, 'ra': 14, 'sa': 15, 'ta': 16, 'tha': 17, 'wa': 18, 'ya': 19}

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), padding = "same", activation = "relu", input_shape = (100, 100, 1)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), padding = "same", activation = "relu"),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), padding = "same", activation = "relu"),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), padding = "same", activation = "relu"),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),                       # Untuk menghindari terjadinya overfitting
    tf.keras.layers.Dense(512, activation = "relu"),
    tf.keras.layers.Dense(20, activation = "softmax")   # Gunakan softmax untuk klasifikasi 3 kelas atau lebih,
])                                                      # untuk klasifikasi dua kelas gunakan sigmoid

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 100, 100, 32)      320
#
#  max_pooling2d (MaxPooling2  (None, 50, 50, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 25, 25, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 12, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dropout (Dropout)           (None, 4608)              0
#
#  dense (Dense)               (None, 512)               2359808
#
#  dense_1 (Dense)             (None, 20)                10260
#
# =================================================================
# Total params: 2610324 (9.96 MB)
# Trainable params: 2610324 (9.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(                            # Gunakan categorical_crossentropy untuk klasifikasi 3 kelas atau lebih,
    loss = "categorical_crossentropy",    # untuk klasifikasi dua kelas gunakan binary_crossentropy
    optimizer = tf.optimizers.Adam(
        learning_rate = 0.0003            # Learning rate 0.0003 ( default = 0.001 ) untuk menghindari terjadinya overfitting
    ),
    metrics = ["accuracy"]
)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

checkpoint = ModelCheckpoint("model.h5", monitor = "val_accuracy", mode = "auto", save_best_only = True, verbose = 1)
earlystop = EarlyStopping(monitor = "val_accuracy", min_delta = 0, patience = 10, verbose = 1, restore_best_weights = True)

# %%
STEP_PER_EPOCH = train_generator.n // train_generator.batch_size
VALIDATION_STEPS = validation_generator.n // validation_generator.batch_size

history = model.fit(
    train_generator,
    steps_per_epoch = STEP_PER_EPOCH,
    epochs = 100,
    validation_data = validation_generator,
    validation_steps = VALIDATION_STEPS,
    verbose = 1,
    callbacks = [checkpoint, earlystop]
)
# Out:
# Epoch 1/100
# 255/255 [==============================] - ETA: 0s - loss: 2.8249 - accuracy: 0.1108
# Epoch 1: val_accuracy improved from -inf to 0.22966, saving model to model.h5
# 255/255 [==============================] - 245s 952ms/step - loss: 2.8249 - accuracy: 0.1108 - val_loss: 2.4495 - val_accuracy: 0.2297
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2/100
# 255/255 [==============================] - ETA: 0s - loss: 1.9429 - accuracy: 0.4001
# Epoch 2: val_accuracy improved from 0.22966 to 0.54911, saving model to model.h5
# 255/255 [==============================] - 237s 931ms/step - loss: 1.9429 - accuracy: 0.4001 - val_loss: 1.4646 - val_accuracy: 0.5491
# Epoch 3/100
# 255/255 [==============================] - ETA: 0s - loss: 1.3154 - accuracy: 0.5893
# Epoch 3: val_accuracy improved from 0.54911 to 0.70933, saving model to model.h5
# 255/255 [==============================] - 243s 955ms/step - loss: 1.3154 - accuracy: 0.5893 - val_loss: 0.9474 - val_accuracy: 0.7093
# Epoch 4/100
# 255/255 [==============================] - ETA: 0s - loss: 0.9628 - accuracy: 0.6922
# Epoch 4: val_accuracy improved from 0.70933 to 0.73065, saving model to model.h5
# 255/255 [==============================] - 236s 922ms/step - loss: 0.9628 - accuracy: 0.6922 - val_loss: 0.8236 - val_accuracy: 0.7307
# Epoch 5/100
# 255/255 [==============================] - ETA: 0s - loss: 0.7613 - accuracy: 0.7559
# Epoch 5: val_accuracy improved from 0.73065 to 0.83135, saving model to model.h5
# 255/255 [==============================] - 232s 909ms/step - loss: 0.7613 - accuracy: 0.7559 - val_loss: 0.5908 - val_accuracy: 0.8313
# Epoch 6/100
# 255/255 [==============================] - ETA: 0s - loss: 0.6280 - accuracy: 0.7988
# Epoch 6: val_accuracy improved from 0.83135 to 0.86855, saving model to model.h5
# 255/255 [==============================] - 243s 955ms/step - loss: 0.6280 - accuracy: 0.7988 - val_loss: 0.4777 - val_accuracy: 0.8686
# Epoch 7/100
# 255/255 [==============================] - ETA: 0s - loss: 0.5325 - accuracy: 0.8325
# Epoch 7: val_accuracy did not improve from 0.86855
# 255/255 [==============================] - 235s 924ms/step - loss: 0.5325 - accuracy: 0.8325 - val_loss: 0.4433 - val_accuracy: 0.8686
# Epoch 8/100
# 255/255 [==============================] - ETA: 0s - loss: 0.4567 - accuracy: 0.8511
# Epoch 8: val_accuracy improved from 0.86855 to 0.89335, saving model to model.h5
# 255/255 [==============================] - 244s 955ms/step - loss: 0.4567 - accuracy: 0.8511 - val_loss: 0.3767 - val_accuracy: 0.8934
# Epoch 9/100
# 255/255 [==============================] - ETA: 0s - loss: 0.4240 - accuracy: 0.8627
# Epoch 9: val_accuracy did not improve from 0.89335
# 255/255 [==============================] - 231s 907ms/step - loss: 0.4240 - accuracy: 0.8627 - val_loss: 0.3819 - val_accuracy: 0.8919
# Epoch 10/100
# 255/255 [==============================] - ETA: 0s - loss: 0.3726 - accuracy: 0.8783
# Epoch 10: val_accuracy improved from 0.89335 to 0.89782, saving model to model.h5
# 255/255 [==============================] - 239s 939ms/step - loss: 0.3726 - accuracy: 0.8783 - val_loss: 0.3539 - val_accuracy: 0.8978
# Epoch 11/100
# 255/255 [==============================] - ETA: 0s - loss: 0.3691 - accuracy: 0.8824
# Epoch 11: val_accuracy improved from 0.89782 to 0.91270, saving model to model.h5
# 255/255 [==============================] - 241s 945ms/step - loss: 0.3691 - accuracy: 0.8824 - val_loss: 0.3165 - val_accuracy: 0.9127
# Epoch 12/100
# 255/255 [==============================] - ETA: 0s - loss: 0.3281 - accuracy: 0.8923
# Epoch 12: val_accuracy improved from 0.91270 to 0.91419, saving model to model.h5
# 255/255 [==============================] - 236s 924ms/step - loss: 0.3281 - accuracy: 0.8923 - val_loss: 0.3029 - val_accuracy: 0.9142
# Epoch 13/100
# 255/255 [==============================] - ETA: 0s - loss: 0.2910 - accuracy: 0.9066
# Epoch 13: val_accuracy improved from 0.91419 to 0.91766, saving model to model.h5
# 255/255 [==============================] - 240s 940ms/step - loss: 0.2910 - accuracy: 0.9066 - val_loss: 0.2751 - val_accuracy: 0.9177
# Epoch 14/100
# 255/255 [==============================] - ETA: 0s - loss: 0.2830 - accuracy: 0.9037
# Epoch 14: val_accuracy did not improve from 0.91766
# 255/255 [==============================] - 234s 916ms/step - loss: 0.2830 - accuracy: 0.9037 - val_loss: 0.3282 - val_accuracy: 0.9023
# Epoch 15/100
# 255/255 [==============================] - ETA: 0s - loss: 0.2559 - accuracy: 0.9142
# Epoch 15: val_accuracy improved from 0.91766 to 0.92758, saving model to model.h5
# 255/255 [==============================] - 228s 895ms/step - loss: 0.2559 - accuracy: 0.9142 - val_loss: 0.2660 - val_accuracy: 0.9276
# Epoch 16/100
# 255/255 [==============================] - ETA: 0s - loss: 0.2473 - accuracy: 0.9186
# Epoch 16: val_accuracy did not improve from 0.92758
# 255/255 [==============================] - 240s 940ms/step - loss: 0.2473 - accuracy: 0.9186 - val_loss: 0.2430 - val_accuracy: 0.9261
# Epoch 17/100
# 255/255 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.9234
# Epoch 17: val_accuracy did not improve from 0.92758
# 255/255 [==============================] - 234s 915ms/step - loss: 0.2261 - accuracy: 0.9234 - val_loss: 0.3192 - val_accuracy: 0.9053
# Epoch 18/100
# 255/255 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9284
# Epoch 18: val_accuracy improved from 0.92758 to 0.93700, saving model to model.h5
# 255/255 [==============================] - 238s 935ms/step - loss: 0.2175 - accuracy: 0.9284 - val_loss: 0.2357 - val_accuracy: 0.9370
# Epoch 19/100
# 255/255 [==============================] - ETA: 0s - loss: 0.2036 - accuracy: 0.9355
# Epoch 19: val_accuracy improved from 0.93700 to 0.94296, saving model to model.h5
# 255/255 [==============================] - 232s 909ms/step - loss: 0.2036 - accuracy: 0.9355 - val_loss: 0.1925 - val_accuracy: 0.9430
# Epoch 20/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1827 - accuracy: 0.9408
# Epoch 20: val_accuracy improved from 0.94296 to 0.94395, saving model to model.h5
# 255/255 [==============================] - 231s 908ms/step - loss: 0.1827 - accuracy: 0.9408 - val_loss: 0.2053 - val_accuracy: 0.9439
# Epoch 21/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.9362
# Epoch 21: val_accuracy did not improve from 0.94395
# 255/255 [==============================] - 236s 925ms/step - loss: 0.1945 - accuracy: 0.9362 - val_loss: 0.2191 - val_accuracy: 0.9360
# Epoch 22/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1737 - accuracy: 0.9429
# Epoch 22: val_accuracy improved from 0.94395 to 0.94692, saving model to model.h5
# 255/255 [==============================] - 236s 922ms/step - loss: 0.1737 - accuracy: 0.9429 - val_loss: 0.1865 - val_accuracy: 0.9469
# Epoch 23/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1661 - accuracy: 0.9458
# Epoch 23: val_accuracy did not improve from 0.94692
# 255/255 [==============================] - 232s 912ms/step - loss: 0.1661 - accuracy: 0.9458 - val_loss: 0.2095 - val_accuracy: 0.9405
# Epoch 24/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1566 - accuracy: 0.9482
# Epoch 24: val_accuracy did not improve from 0.94692
# 255/255 [==============================] - 231s 907ms/step - loss: 0.1566 - accuracy: 0.9482 - val_loss: 0.1976 - val_accuracy: 0.9400
# Epoch 25/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9483
# Epoch 25: val_accuracy did not improve from 0.94692
# 255/255 [==============================] - 232s 911ms/step - loss: 0.1606 - accuracy: 0.9483 - val_loss: 0.2025 - val_accuracy: 0.9360
# Epoch 26/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1398 - accuracy: 0.9526
# Epoch 26: val_accuracy improved from 0.94692 to 0.95188, saving model to model.h5
# 255/255 [==============================] - 231s 906ms/step - loss: 0.1398 - accuracy: 0.9526 - val_loss: 0.1732 - val_accuracy: 0.9519
# Epoch 27/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.9489
# Epoch 27: val_accuracy did not improve from 0.95188
# 255/255 [==============================] - 235s 921ms/step - loss: 0.1486 - accuracy: 0.9489 - val_loss: 0.1690 - val_accuracy: 0.9499
# Epoch 28/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.9525
# Epoch 28: val_accuracy did not improve from 0.95188
# 255/255 [==============================] - 234s 917ms/step - loss: 0.1442 - accuracy: 0.9525 - val_loss: 0.2043 - val_accuracy: 0.9454
# Epoch 29/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9547
# Epoch 29: val_accuracy did not improve from 0.95188
# 255/255 [==============================] - 231s 908ms/step - loss: 0.1352 - accuracy: 0.9547 - val_loss: 0.1853 - val_accuracy: 0.9494
# Epoch 30/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1391 - accuracy: 0.9544
# Epoch 30: val_accuracy did not improve from 0.95188
# 255/255 [==============================] - 231s 908ms/step - loss: 0.1391 - accuracy: 0.9544 - val_loss: 0.1794 - val_accuracy: 0.9425
# Epoch 31/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.9612
# Epoch 31: val_accuracy did not improve from 0.95188
# 255/255 [==============================] - 241s 947ms/step - loss: 0.1206 - accuracy: 0.9612 - val_loss: 0.1872 - val_accuracy: 0.9474
# Epoch 32/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9576
# Epoch 32: val_accuracy improved from 0.95188 to 0.95437, saving model to model.h5
# 255/255 [==============================] - 242s 951ms/step - loss: 0.1233 - accuracy: 0.9576 - val_loss: 0.1536 - val_accuracy: 0.9544
# Epoch 33/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1138 - accuracy: 0.9613
# Epoch 33: val_accuracy did not improve from 0.95437
# 255/255 [==============================] - 236s 927ms/step - loss: 0.1138 - accuracy: 0.9613 - val_loss: 0.1660 - val_accuracy: 0.9514
# Epoch 34/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9602
# Epoch 34: val_accuracy improved from 0.95437 to 0.95536, saving model to model.h5
# 255/255 [==============================] - 239s 938ms/step - loss: 0.1142 - accuracy: 0.9602 - val_loss: 0.1637 - val_accuracy: 0.9554
# Epoch 35/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9613
# Epoch 35: val_accuracy did not improve from 0.95536
# 255/255 [==============================] - 237s 929ms/step - loss: 0.1148 - accuracy: 0.9613 - val_loss: 0.1578 - val_accuracy: 0.9534
# Epoch 36/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1104 - accuracy: 0.9618
# Epoch 36: val_accuracy did not improve from 0.95536
# 255/255 [==============================] - 232s 909ms/step - loss: 0.1104 - accuracy: 0.9618 - val_loss: 0.1825 - val_accuracy: 0.9519
# Epoch 37/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9637
# Epoch 37: val_accuracy improved from 0.95536 to 0.95784, saving model to model.h5
# 255/255 [==============================] - 231s 904ms/step - loss: 0.1065 - accuracy: 0.9637 - val_loss: 0.1591 - val_accuracy: 0.9578
# Epoch 38/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0976 - accuracy: 0.9664
# Epoch 38: val_accuracy did not improve from 0.95784
# 255/255 [==============================] - 238s 935ms/step - loss: 0.0976 - accuracy: 0.9664 - val_loss: 0.1703 - val_accuracy: 0.9539
# Epoch 39/100
# 255/255 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9673
# Epoch 39: val_accuracy improved from 0.95784 to 0.96379, saving model to model.h5
# 255/255 [==============================] - 237s 931ms/step - loss: 0.1013 - accuracy: 0.9673 - val_loss: 0.1322 - val_accuracy: 0.9638
# Epoch 40/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9675
# Epoch 40: val_accuracy did not improve from 0.96379
# 255/255 [==============================] - 234s 918ms/step - loss: 0.0989 - accuracy: 0.9675 - val_loss: 0.1704 - val_accuracy: 0.9494
# Epoch 41/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9688
# Epoch 41: val_accuracy did not improve from 0.96379
# 255/255 [==============================] - 240s 943ms/step - loss: 0.0961 - accuracy: 0.9688 - val_loss: 0.1714 - val_accuracy: 0.9524
# Epoch 42/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0950 - accuracy: 0.9688
# Epoch 42: val_accuracy did not improve from 0.96379
# 255/255 [==============================] - 233s 913ms/step - loss: 0.0950 - accuracy: 0.9688 - val_loss: 0.1681 - val_accuracy: 0.9568
# Epoch 43/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9711
# Epoch 43: val_accuracy improved from 0.96379 to 0.96478, saving model to model.h5
# 255/255 [==============================] - 237s 930ms/step - loss: 0.0899 - accuracy: 0.9711 - val_loss: 0.1445 - val_accuracy: 0.9648
# Epoch 44/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0857 - accuracy: 0.9707
# Epoch 44: val_accuracy improved from 0.96478 to 0.96577, saving model to model.h5
# 255/255 [==============================] - 238s 934ms/step - loss: 0.0857 - accuracy: 0.9707 - val_loss: 0.1237 - val_accuracy: 0.9658
# Epoch 45/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0847 - accuracy: 0.9706
# Epoch 45: val_accuracy did not improve from 0.96577
# 255/255 [==============================] - 239s 937ms/step - loss: 0.0847 - accuracy: 0.9706 - val_loss: 0.1490 - val_accuracy: 0.9578
# Epoch 46/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9714
# Epoch 46: val_accuracy did not improve from 0.96577
# 255/255 [==============================] - 238s 929ms/step - loss: 0.0837 - accuracy: 0.9714 - val_loss: 0.1727 - val_accuracy: 0.9529
# Epoch 47/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9748
# Epoch 47: val_accuracy did not improve from 0.96577
# 255/255 [==============================] - 235s 921ms/step - loss: 0.0775 - accuracy: 0.9748 - val_loss: 0.1477 - val_accuracy: 0.9598
# Epoch 48/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9757
# Epoch 48: val_accuracy did not improve from 0.96577
# 255/255 [==============================] - 235s 923ms/step - loss: 0.0796 - accuracy: 0.9757 - val_loss: 0.1419 - val_accuracy: 0.9598
# Epoch 49/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0740 - accuracy: 0.9744
# Epoch 49: val_accuracy did not improve from 0.96577
# 255/255 [==============================] - 236s 926ms/step - loss: 0.0740 - accuracy: 0.9744 - val_loss: 0.1596 - val_accuracy: 0.9554
# Epoch 50/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0816 - accuracy: 0.9730
# Epoch 50: val_accuracy did not improve from 0.96577
# 255/255 [==============================] - 240s 940ms/step - loss: 0.0816 - accuracy: 0.9730 - val_loss: 0.1467 - val_accuracy: 0.9578
# Epoch 51/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9770
# Epoch 51: val_accuracy did not improve from 0.96577
# 255/255 [==============================] - 232s 912ms/step - loss: 0.0753 - accuracy: 0.9770 - val_loss: 0.1314 - val_accuracy: 0.9648
# Epoch 52/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0854 - accuracy: 0.9740
# Epoch 52: val_accuracy did not improve from 0.96577
# 255/255 [==============================] - 237s 926ms/step - loss: 0.0854 - accuracy: 0.9740 - val_loss: 0.1400 - val_accuracy: 0.9638
# Epoch 53/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9756
# Epoch 53: val_accuracy improved from 0.96577 to 0.96627, saving model to model.h5
# 255/255 [==============================] - 237s 930ms/step - loss: 0.0741 - accuracy: 0.9756 - val_loss: 0.1288 - val_accuracy: 0.9663
# Epoch 54/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0642 - accuracy: 0.9809
# Epoch 54: val_accuracy did not improve from 0.96627
# 255/255 [==============================] - 233s 916ms/step - loss: 0.0642 - accuracy: 0.9809 - val_loss: 0.1489 - val_accuracy: 0.9623
# Epoch 55/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9777
# Epoch 55: val_accuracy did not improve from 0.96627
# 255/255 [==============================] - 230s 903ms/step - loss: 0.0677 - accuracy: 0.9777 - val_loss: 0.1405 - val_accuracy: 0.9618
# Epoch 56/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9745
# Epoch 56: val_accuracy improved from 0.96627 to 0.96825, saving model to model.h5
# 255/255 [==============================] - 234s 920ms/step - loss: 0.0753 - accuracy: 0.9745 - val_loss: 0.1201 - val_accuracy: 0.9683
# Epoch 57/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9768
# Epoch 57: val_accuracy did not improve from 0.96825
# 255/255 [==============================] - 238s 933ms/step - loss: 0.0694 - accuracy: 0.9768 - val_loss: 0.1456 - val_accuracy: 0.9583
# Epoch 58/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9797
# Epoch 58: val_accuracy did not improve from 0.96825
# 255/255 [==============================] - 225s 883ms/step - loss: 0.0634 - accuracy: 0.9797 - val_loss: 0.1502 - val_accuracy: 0.9628
# Epoch 59/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9809
# Epoch 59: val_accuracy did not improve from 0.96825
# 255/255 [==============================] - 232s 909ms/step - loss: 0.0591 - accuracy: 0.9809 - val_loss: 0.1426 - val_accuracy: 0.9623
# Epoch 60/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.9793
# Epoch 60: val_accuracy did not improve from 0.96825
# 255/255 [==============================] - 236s 925ms/step - loss: 0.0660 - accuracy: 0.9793 - val_loss: 0.1475 - val_accuracy: 0.9623
# Epoch 61/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9754
# Epoch 61: val_accuracy did not improve from 0.96825
# 255/255 [==============================] - 231s 905ms/step - loss: 0.0672 - accuracy: 0.9754 - val_loss: 0.1450 - val_accuracy: 0.9593
# Epoch 62/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9757
# Epoch 62: val_accuracy did not improve from 0.96825
# 255/255 [==============================] - 233s 913ms/step - loss: 0.0651 - accuracy: 0.9757 - val_loss: 0.1410 - val_accuracy: 0.9633
# Epoch 63/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0624 - accuracy: 0.9784
# Epoch 63: val_accuracy did not improve from 0.96825
# 255/255 [==============================] - 233s 912ms/step - loss: 0.0624 - accuracy: 0.9784 - val_loss: 0.1152 - val_accuracy: 0.9673
# Epoch 64/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9779
# Epoch 64: val_accuracy did not improve from 0.96825
# 255/255 [==============================] - 234s 920ms/step - loss: 0.0627 - accuracy: 0.9779 - val_loss: 0.1307 - val_accuracy: 0.9673
# Epoch 65/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9806
# Epoch 65: val_accuracy did not improve from 0.96825
# 255/255 [==============================] - 236s 926ms/step - loss: 0.0572 - accuracy: 0.9806 - val_loss: 0.1221 - val_accuracy: 0.9623
# Epoch 66/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9793
# Epoch 66: val_accuracy improved from 0.96825 to 0.96925, saving model to model.h5
# 255/255 [==============================] - 237s 931ms/step - loss: 0.0580 - accuracy: 0.9793 - val_loss: 0.1276 - val_accuracy: 0.9692
# Epoch 67/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9804
# Epoch 67: val_accuracy did not improve from 0.96925
# 255/255 [==============================] - 235s 922ms/step - loss: 0.0589 - accuracy: 0.9804 - val_loss: 0.1563 - val_accuracy: 0.9638
# Epoch 68/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.9790
# Epoch 68: val_accuracy did not improve from 0.96925
# 255/255 [==============================] - 234s 919ms/step - loss: 0.0596 - accuracy: 0.9790 - val_loss: 0.1515 - val_accuracy: 0.9618
# Epoch 69/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9799
# Epoch 69: val_accuracy did not improve from 0.96925
# 255/255 [==============================] - 230s 902ms/step - loss: 0.0581 - accuracy: 0.9799 - val_loss: 0.1387 - val_accuracy: 0.9658
# Epoch 70/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9798
# Epoch 70: val_accuracy did not improve from 0.96925
# 255/255 [==============================] - 228s 894ms/step - loss: 0.0536 - accuracy: 0.9798 - val_loss: 0.1275 - val_accuracy: 0.9673
# Epoch 71/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0497 - accuracy: 0.9827
# Epoch 71: val_accuracy did not improve from 0.96925
# 255/255 [==============================] - 233s 911ms/step - loss: 0.0497 - accuracy: 0.9827 - val_loss: 0.1437 - val_accuracy: 0.9688
# Epoch 72/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9819
# Epoch 72: val_accuracy did not improve from 0.96925
# 255/255 [==============================] - 236s 925ms/step - loss: 0.0528 - accuracy: 0.9819 - val_loss: 0.1284 - val_accuracy: 0.9673
# Epoch 73/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9837
# Epoch 73: val_accuracy did not improve from 0.96925
# 255/255 [==============================] - 233s 914ms/step - loss: 0.0488 - accuracy: 0.9837 - val_loss: 0.1309 - val_accuracy: 0.9683
# Epoch 74/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9825
# Epoch 74: val_accuracy did not improve from 0.96925
# 255/255 [==============================] - 235s 922ms/step - loss: 0.0535 - accuracy: 0.9825 - val_loss: 0.1145 - val_accuracy: 0.9673
# Epoch 75/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9830
# Epoch 75: val_accuracy did not improve from 0.96925
# 255/255 [==============================] - 237s 929ms/step - loss: 0.0499 - accuracy: 0.9830 - val_loss: 0.1388 - val_accuracy: 0.9668
# Epoch 76/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9858
# Epoch 76: val_accuracy improved from 0.96925 to 0.97272, saving model to model.h5
# 255/255 [==============================] - 231s 904ms/step - loss: 0.0444 - accuracy: 0.9858 - val_loss: 0.1186 - val_accuracy: 0.9727
# Epoch 77/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9820
# Epoch 77: val_accuracy did not improve from 0.97272
# 255/255 [==============================] - 236s 925ms/step - loss: 0.0539 - accuracy: 0.9820 - val_loss: 0.1393 - val_accuracy: 0.9653
# Epoch 78/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9852
# Epoch 78: val_accuracy did not improve from 0.97272
# 255/255 [==============================] - 236s 927ms/step - loss: 0.0442 - accuracy: 0.9852 - val_loss: 0.1293 - val_accuracy: 0.9678
# Epoch 79/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9816
# Epoch 79: val_accuracy did not improve from 0.97272
# 255/255 [==============================] - 231s 904ms/step - loss: 0.0587 - accuracy: 0.9816 - val_loss: 0.1487 - val_accuracy: 0.9544
# Epoch 80/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9847
# Epoch 80: val_accuracy did not improve from 0.97272
# 255/255 [==============================] - 231s 905ms/step - loss: 0.0480 - accuracy: 0.9847 - val_loss: 0.1392 - val_accuracy: 0.9673
# Epoch 81/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9860
# Epoch 81: val_accuracy did not improve from 0.97272
# 255/255 [==============================] - 231s 905ms/step - loss: 0.0456 - accuracy: 0.9860 - val_loss: 0.1295 - val_accuracy: 0.9683
# Epoch 82/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9841
# Epoch 82: val_accuracy did not improve from 0.97272
# 255/255 [==============================] - 234s 918ms/step - loss: 0.0436 - accuracy: 0.9841 - val_loss: 0.1370 - val_accuracy: 0.9663
# Epoch 83/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9826
# Epoch 83: val_accuracy did not improve from 0.97272
# 255/255 [==============================] - 234s 917ms/step - loss: 0.0500 - accuracy: 0.9826 - val_loss: 0.1481 - val_accuracy: 0.9643
# Epoch 84/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9831
# Epoch 84: val_accuracy did not improve from 0.97272
# 255/255 [==============================] - 264s 1s/step - loss: 0.0479 - accuracy: 0.9831 - val_loss: 0.1328 - val_accuracy: 0.9643
# Epoch 85/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9827
# Epoch 85: val_accuracy did not improve from 0.97272
# 255/255 [==============================] - 268s 1s/step - loss: 0.0511 - accuracy: 0.9827 - val_loss: 0.1319 - val_accuracy: 0.9688
# Epoch 86/100
# 255/255 [==============================] - ETA: 0s - loss: 0.0377 - accuracy: 0.9871
# Epoch 86: val_accuracy did not improve from 0.97272
# Restoring model weights from the end of the best epoch: 76.
# 255/255 [==============================] - 259s 1s/step - loss: 0.0377 - accuracy: 0.9871 - val_loss: 0.1383 - val_accuracy: 0.9673
# Epoch 86: early stopping

# %%
import matplotlib.pyplot as plt

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

plt.style.use("seaborn")
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 5))

ax[0].plot(acc, label = "Training Accuracy")
ax[0].plot(val_acc, label = "Validation Accuracy")
ax[0].legend(loc = "lower right")
ax[0].set_title("Model Accuracy", fontsize = 16)
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Accuracy")

ax[1].plot(loss, label = "Training Loss")
ax[1].plot(val_loss, label = "Validation Loss")
ax[1].legend(loc = "upper right")
ax[1].set_title("Model Loss", fontsize = 16)
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Loss")

plt.show()
# Out:
# <ipython-input-11-ff10d37cf498>:9: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
# !cp /content/model.h5 "/content/gdrive/My Drive/Hanacaraka"

# %%
from keras.models import load_model

load_model = load_model("/content/model.h5")

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.preprocessing import image

classes = [
    "ba", "ca", "da", "dha", "ga", "ha", "ja", "ka", "la", "ma",
    "na", "nga", "nya", "pa", "ra", "sa", "ta", "tha", "wa", "ya"
]

path = "/content/gdrive/MyDrive/prediction"
fig, ax = plt.subplots(nrows = 4, ncols = 5, figsize = (20, 20))
# Muat model dengan nama variabel yang berbeda untuk menghindari penimpaan fungsi
model = load_model("/content/model.h5")

x = 0
for y, img_name in enumerate(os.listdir(path)):
    img_path = "{}{}{}".format(path, "/", img_name)
    img = image.load_img(img_path, color_mode = "grayscale", target_size = (100, 100))

    img = image.img_to_array(img)
    img = np.expand_dims(img, axis = 0)

     # Gunakan variabel 'model' untuk prediksi
    result = model.predict(img)

    img_preview = mpimg.imread(img_path)

    if (y > 1) and (y % 5 == 0):
        x += 1

    ax[x, (y % 5)].set_title("{} / prediction: {}".format(img_name, classes[np.argmax(result)]))
    ax[x, (y % 5)].imshow(img_preview)
# Out:
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 58ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from keras.models import load_model
from keras.preprocessing import image

# Load model Keras (pastikan model telah disimpan di path yang sesuai)
model = load_model('/content/model.h5')

# Fungsi untuk memprediksi kelas dari gambar
def classify_image(img_path):
    classes = [
        "ba", "ca", "da", "dha", "ga", "ha", "ja", "ka", "la", "ma",
        "na", "nga", "nya", "pa", "ra", "sa", "ta", "tha", "wa", "ya"
    ]

    img = image.load_img(img_path, color_mode="grayscale", target_size=(100, 100))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    prediction = model.predict(img_array)
    predicted_class = classes[np.argmax(prediction)]

    return predicted_class, img

# Contoh penggunaan
img_path = '/content/gdrive/MyDrive/images/temp.png'
predicted_class, img = classify_image(img_path)
print(f"Result: {predicted_class}")


# Menampilkan gambar
plt.imshow(img, cmap='gray')
plt.title(f"Predicted: {predicted_class}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 133ms/step
# Result: ha
